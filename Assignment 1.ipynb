# %% [markdown]
# # Assignment 1: Data Preprocessing and Exploratory Data Analysis
#
# **Student Name:** Samson Silver
# **Sudetn ID:** 815337747
# **Points:** 10 (8 points for Assignment + 2 points for survey)
#
# ## Assignment Overview
# You will work with the "Salary Survey" dataset, which contains salary information and workplace characteristics from thousands of respondents. This dataset presents typical challenges found in real-world data science projects.
#
# ## Dataset Information
# - **File:** `salary_survey.csv`
# - **Content:** Salary information and workplace characteristics

# %% [markdown]
# ## Import Required Libraries
# Import all necessary libraries for data analysis, visualization, and preprocessing.

# %%
# Import necessary libraries for data analysis and visualization
import numpy as np
import pandas as pd
from matplotlib.pyplot import subplots

# %% [markdown]
# # Task 1: Data Description and Exploration (2 Points)
#
# ## 1.1 Dataset Overview
# **Instructions:**
# - Load the dataset from the CSV file `salary_survey.csv`
# - Display basic statistics (shape, columns, data types)
# - Create a comprehensive data dictionary explaining each variable
# - Identify potential target variable(s) for future modeling

# %%
# Load the dataset
# TODO: Load the CSV file into a pandas DataFrame

# YOUR CODE HERE:
Salary = pd.read_csv('salary_survey.csv')

# Display basic information about the dataset
# TODO: Show the shape of the dataset
# TODO: Display column names and data types
# TODO: Show the first few rows

# YOUR CODE HERE:
print(Salary.shape, '\n')
print(Salary.columns, '\n')
print(Salary.dtypes, '\n')
print(Salary[:7], '\n')

# Create basic statistics summary
# TODO: Use describe() for numerical columns
# TODO: Use info() to see data types and non-null counts

# YOUR CODE HERE:
print(Salary.describe(), '\n')
print(Salary.info())
# Out:
# (27940, 18)
#
# Index(['Timestamp', 'How old are you?', 'What industry do you work in?',
#        'Job title',
#        'If your job title needs additional context, please clarify here:',
#        'What is your annual salary? (You'll indicate the currency in a later question. If you are part-time or hourly, please enter an annualized equivalent -- what you would earn if you worked the job 40 hours a week, 52 weeks a year.)',
#        'How much additional monetary compensation do you get, if any (for example, bonuses or overtime in an average year)? Please only include monetary compensation here, not the value of benefits.',
#        'Please indicate the currency',
#        'If "Other," please indicate the currency here: ',
#        'If your income needs additional context, please provide it here:',
#        'What country do you work in?',
#        'If you're in the U.S., what state do you work in?',
#        'What city do you work in?',
# ...

# %%
# Create a comprehensive data dictionary
# TODO: For each column, provide a description of what it represents
# TODO: Identify data types and possible values
# TODO: Note any patterns or conventions in the data


# YOUR CODE HERE:



# Identify potential target variables
# TODO: Based on the assignment context (salary survey), identify potential target variables
# TODO: Consider which variables might be predicted in future modeling

# List and justify potential target variables

# %% [markdown]
# Timestamp
# Description: Date and time when the survey response was submitted.
# Data type: String
# Possible values: "4/27/2021 11:02:10"
# Pattern: Values are provided in standard date-time format mm/dd/yyyy hh:mm:ss.
#
# How old are you?
# Description: Age of the participant.
# Data type: Categorical
# Possible values: "18-24", "25-34", "35-44", etc.
# Pattern: Age given as categories, not exact numbers.
#
# What industry do you work in?
# Description: Industry of employment.
# Data type: Categorical
# Possible values: "Education (Higher Education)", "Computing or Tech", "Accounting, Banking & Finance", etc.
# Pattern: Industry names, sometimes with subcategories.
#
# Job title
# Description: Respondent's job title.
# Data type: String
# Possible values: Any valid job title
# Pattern: Much variation in the data.
#
# If your job title needs additional context, please clarify here:
# Description: Additional details about the job title.
# Data type: String
# Possible values: Free text, often blank.
# Pattern: Optional field.
#
# What is your annual salary?
# Description: Yearly salary of participant.
# Data type: Float/String
# Possible values: "55,000", "34,000", etc.
# Pattern: May contain commas, needs conversion to numeric.
#
# How much additional monetary compensation do you get, if any
# Description: Additional compensation (bonuses, overtime, etc.).
# Data type: String/Float
# Possible values: Numbers similar to previous column, or possibly left blank.
# Pattern: May be blank if not applicable.
#
# Please indicate the currency
# Description: Currency of salary.
# Data type: Categorical
# Possible values: "USD", "GBP", etc.
# Pattern: Three-letter currency codes.
#
# If 'Other,' please indicate the currency here:
# Description: Currency if not listed in previous column.
# Data type: String
# Possible values: Free text, often blank.
# Pattern: Optional field.
#
# If your income needs additional context, please provide it here:
# Description: Additional context about income.
# Data type: String
# Possible values: Free text, often blank.
# Pattern: Optional field.
#
# What country do you work in?
# Description: Country of employment.
# Data type: Categorical
# Possible values: "United States", "United Kingdom", etc.
# Pattern: Country names.
#
# If you're in the U.S., what state do you work in?
# Description: State of employment (if in the U.S.).
# Data type: Categorical
# Possible values: "Massachusetts", "Tennessee", etc.
# Pattern: Only filled if country is United States.
#
# What city do you work in?
# Description: City of employment.
# Data type: String
# Possible values: "Boston", "Columbia," etc.
# Pattern: Varies widely.
#
# How many years of professional work experience do you have overall?
# Description: Total years of professional experience.
# Data type: Categorical
# Possible values: "2-4 years", "5-7 years", "8-10 years", etc.
# Pattern: Experience given as ranges.
#
# How many years of professional work experience do you have in your field?
# Description: Years of experience in current field.
# Data type: Categorical
# Possible values: "2-4 years", "5-7 years", etc.
# Pattern: Experience given as ranges.
#
# What is your highest level of education completed?
# Description: Highest education level.
# Data type: Categorical
# Possible values: "College degree", "Master's degree", "PhD", etc.
# Pattern: Consistent labels, may have variations.
#
# What is your gender?
# Description: Gender identity.
# Data type: Categorical
# Possible values: "Woman", "Non-binary", "Man", etc.
# Pattern: Consistent labels.
#
# What is your race? (Choose all that apply.)
# Description: Race/ethnicity.
# Data type: String
# Possible values: "White", "Black", "Asian", etc. (may be multiple values separated by commas)
# Pattern: Multiple values possible, separated by commas.
#
# Potential target variables:
# Annual salary: This one seems most likely as a target variable, since individuals may want to know how much they will make given their situations as described by the other columns.
# What is your highest level of education completed?: There may be an interest in seeing how salary data corresponds to the level of education received.
# Gender or Race: Both of these may hold interest as target variables to those interested in the relation between salary and demographics.

# %% [markdown]
# ### 📝 Analysis Explanation (Task 1.1)
# **Instructions:** Write your own analysis and interpretation of the dataset overview results.
#
# **Your Analysis:**
# [Write your observations about the dataset structure, size, column types, and initial insights here]
#
# ---

# %% [markdown]
# The salary survey dataset includes a mix of demographic and job-related information, with most columns being categorical or text. Annual salary stands out as the main variable to predict, but factors like education, gender, and race could also be interesting. Some columns need cleaning, especially salary values and free-text fields. Overall, the data looks well-structured for exploring what influences salary, but I’ll need to watch out for missing values and formatting issues.

# %% [markdown]
# ### 🤖 AI-Assisted Analysis (Task 1.1)
# **Instructions:** Use AI tools to help analyze the results and write additional insights.
#
# **AI-Assisted Analysis:**
# [Use AI to help interpret the dataset characteristics, suggest potential issues to investigate, and provide additional context]

# %% [markdown]
# The salary survey dataset contains a diverse set of columns capturing demographic, professional, and compensation-related information from respondents. The structure includes categorical variables (such as age group, industry, education level, gender, and country), free-text fields (job title, additional context), and numerical fields (annual salary, additional compensation).
#
# Dataset Structure: The data is organized with each row representing a unique survey response. Columns cover personal demographics, job details, compensation, and workplace location.
# Column Types: Most columns are categorical, with some free-text and numerical fields. Categorical variables use consistent labels or ranges (e.g., age groups, education levels), while numerical fields may require cleaning (e.g., salary values with commas).
# Patterns and Conventions: Age and experience are given as ranges, currency is indicated by three-letter codes, and some fields are optional or may be left blank. Free-text fields introduce variability and may need standardization.
# Potential Target Variables: Annual salary is the most likely target for predictive modeling, but education level, gender, or race could also be of interest for analyzing relationships with compensation.
# Initial Insights: The dataset is suitable for exploratory analysis of salary determinants, but attention should be paid to missing values, formatting inconsistencies, and the need for data cleaning, especially in free-text and numerical fields.
# Overall, the dataset provides a rich foundation for analyzing factors influencing salary, with opportunities to explore demographic and professional trends, as well as potential disparities across groups.

# %% [markdown]
# ## 1.2 Initial Data Quality Assessment
# **Instructions:**
# - Calculate missing value percentages for each column
# - Identify potential data quality issues (outliers, inconsistencies, formatting problems)
# - Document observations about data collection methodology

# %%
# Calculate missing value percentages
# TODO: Calculate the percentage of missing values for each column
# TODO: Sort by missing percentage to identify most problematic columns


# YOUR CODE HERE:
missing_percent = Salary.isnull().mean() * 100
missing_percent_sorted = missing_percent.sort_values(ascending=False)
print(missing_percent_sorted, '\n')

# Identify data quality issues
# TODO: Check for duplicate rows
# YOUR CODE HERE:
duplicate_count = Salary.duplicated().sum()
print(f"Number of duplicate rows: {duplicate_count} \n")

# TODO: Identify columns with inconsistent formatting
# YOUR CODE HERE:
# For numerical columns stored as strings (e.g., salary with commas)
for col in Salary.columns:
    if Salary[col].dtype == 'object':
        # Check for numbers stored as strings with commas
        sample = Salary[col].dropna().astype(str).head(20)
        if any(',' in val for val in sample):
            print(f"Column '{col}' may have numbers stored as strings with commas.")

# For categorical columns, check for inconsistent capitalization or extra spaces
for col in Salary.select_dtypes(include='object').columns:
    unique_vals = Salary[col].dropna().unique()
    inconsistent = [val for val in unique_vals if val != val.strip() or val != val.lower()]
    if inconsistent:
        print(f"Column '{col}' may have inconsistent formatting (spaces/capitalization).")
print('\n')

# TODO: Look for outliers in numerical columns
# YOUR CODE HERE:
for col in Salary.select_dtypes(include=[np.number]).columns:
    Q1 = Salary[col].quantile(0.25)
    Q3 = Salary[col].quantile(0.75)
    IQR = Q3 - Q1
    lower_bound = Q1 - 1.5 * IQR
    upper_bound = Q3 + 1.5 * IQR
    outliers = Salary[(Salary[col] < lower_bound) | (Salary[col] > upper_bound)]
    print(f"Column '{col}' has {outliers.shape[0]} outliers.")
print('\n')

# TODO: Check for inconsistent categorical values (e.g., different spellings)
# YOUR CODE HERE:
for col in Salary.select_dtypes(include='object').columns:
    unique_vals = pd.Series(Salary[col].dropna().unique())
    print(f"Column '{col}' unique values (sample):")
    print(unique_vals.sort_values().head(20))
    print('-' * 40)
# Out:
# If "Other," please indicate the currency here:                                                                                                                                                                                          99.302076
# If your income needs additional context, please provide it here:                                                                                                                                                                        89.144596
# If your job title needs additional context, please clarify here:                                                                                                                                                                        74.115963
# How much additional monetary compensation do you get, if any (for example, bonuses or overtime in an average year)? Please only include monetary compensation here, not the value of benefits.                                          25.959198
# ...

# %% [markdown]
# ### 📝 Analysis Explanation (Task 1.2)
# **Instructions:** Analyze the data quality assessment results.
#
# **Your Analysis:**
# [Discuss the missing value patterns, data quality issues identified, and your observations about potential data collection problems]
#
# ---

# %% [markdown]
# There are quite a few missing values in the dataset, especially in optional or sensitive fields like salary and compensation. This probably happened because some people skipped questions or didn’t want to share certain info. I also noticed some duplicate rows and inconsistent formatting, like numbers stored as strings and categories with different spellings or extra spaces. These issues are pretty common in survey data and usually come from manual entry or unclear instructions. Cleaning up these problems will make the analysis much more reliable.

# %% [markdown]
# ### 🤖 AI-Assisted Analysis (Task 1.2)
# **Instructions:** Use AI to help interpret data quality findings.
#
# **AI-Assisted Analysis:**
# [Use AI to help identify potential causes of data quality issues, suggest investigation strategies, and provide industry context for the problems found]

# %% [markdown]
# The salary survey dataset shows several common data quality issues. Missing values are present in multiple columns, which may be due to optional survey questions, respondent fatigue, or sensitive topics like salary and compensation. Duplicate rows could result from repeated submissions or technical glitches during data collection.
#
# Formatting inconsistencies—such as numbers stored as strings with commas, or categorical values with extra spaces or inconsistent capitalization—often arise when data is entered manually or aggregated from different sources. Outliers in numerical columns may reflect data entry errors, extreme cases, or genuine variation in salaries and compensation.
#
# Potential causes include unclear survey instructions, lack of input validation, or merging data from multiple systems. To investigate, you should:
#
# Review survey design and data entry processes.
# Check for patterns in missing data (e.g., are certain groups less likely to answer specific questions?).
# Examine outliers to distinguish between errors and true extremes.
# Standardize categorical values and clean formatting issues.
# In industry, these problems are typical in self-reported survey data and HR datasets. Addressing them improves the reliability of analysis and ensures fair, accurate insights for compensation studies and workforce planning.

# %% [markdown]
# # Task 2: Missing Values Analysis and Imputation (2 Points)
#
# ## 2.1 Missing Data Analysis
# **Instructions:**
# - Create visualizations showing missing data patterns
# - Analyze if missing data appears random or systematic
# - Investigate relationships between missing values in different columns

# %%
# Visualize missing data patterns
# TODO: Create visualizations to understand missing data patterns

# YOUR CODE HERE:


# Create missing data bar chart
# TODO: Show missing data counts by column

# YOUR CODE HERE:
def truncate_labels(labels, maxlen=15):
    return [label[:maxlen] + ('...' if len(label) > maxlen else '') for label in labels]

# Calculate missing values
missing_counts = Salary.isnull().sum()
truncated_labels = truncate_labels(missing_counts.sort_values(ascending=False).index)

# Plot bar chart
fig, ax = subplots(figsize=(12, 7))
missing_counts.sort_values(ascending=False).plot(
    kind='bar', ax=ax, color='skyblue', edgecolor='black'
)
ax.set_title('Missing Values by Column', fontsize=16)
ax.set_ylabel('Count of Missing Values', fontsize=14)
ax.set_xlabel('Column Name', fontsize=14)
ax.set_xticklabels(truncated_labels, rotation=60, ha='right', fontsize=12)
ax.grid(axis='y', linestyle='--', alpha=0.7)
fig.tight_layout()
fig.show()

# Create missing data heatmap showing correlations between missing values
# TODO: Analyze if certain missing values tend to occur together
# YOUR CODE HERE:
# Compute missing indicator matrix
missing_matrix = Salary.isnull().astype(int)

# Compute correlation matrix for missing indicators
missing_corr = missing_matrix.corr()

# Truncate column labels for readability
def truncate_labels(labels, maxlen=15):
    return [label[:maxlen] + ('...' if len(label) > maxlen else '') for label in labels]

truncated_labels = truncate_labels(missing_corr.columns)

# Plot heatmap of missing value correlations
fig, ax = subplots(figsize=(12, 10))
im = ax.imshow(missing_corr, cmap='Blues', interpolation='none')
ax.set_title('Correlation of Missing Values Between Columns', fontsize=16)
ax.set_xticks(np.arange(len(truncated_labels)))
ax.set_yticks(np.arange(len(truncated_labels)))
ax.set_xticklabels(truncated_labels, rotation=90, fontsize=10)
ax.set_yticklabels(truncated_labels, fontsize=10)
fig.colorbar(im, ax=ax, label='Correlation')
fig.tight_layout()
fig.show()


# TODO: Check if missing data appears random or systematic
# TODO: Calculate correlations between missing indicators
# YOUR CODE HERE:
# Create missing indicator matrix
missing_matrix = Salary.isnull().astype(int)

# Calculate correlation matrix for missing indicators
missing_corr = missing_matrix.corr()

# Print the top correlated pairs (excluding self-correlation)
corr_pairs = (
    missing_corr.where(np.triu(np.ones(missing_corr.shape), k=1).astype(bool))
    .stack()
    .sort_values(ascending=False)
)

print("Top correlated missingness pairs (systematic missingness):")
print(corr_pairs.head(10))

print("\nLow or near-zero correlations suggest random missingness between columns.")
# Out:
# C:\Users\Samson Silver\AppData\Local\Temp\ipykernel_24108\1786059545.py:29: UserWarning: FigureCanvasAgg is non-interactive, and thus cannot be shown
#   fig.show()
# C:\Users\Samson Silver\AppData\Local\Temp\ipykernel_24108\1786059545.py:56: UserWarning: FigureCanvasAgg is non-interactive, and thus cannot be shown
#   fig.show()
# Top correlated missingness pairs (systematic missingness):
# What is your gender?                                                                                                                                                                            What is your race? (Choose all that apply.)                                                                                                                                                       0.319291
# ...

# %% [markdown]
# ### 📝 Analysis Explanation (Task 2.1)
# **Your Analysis:**
# [Analyze the missing data patterns and discuss whether they appear random or systematic]
#
# ---

# %% [markdown]
# Some columns have a lot more missing values than others, especially those asking about salary or extra compensation, likely because people skip sensitive or optional questions. The correlation analysis shows that certain columns tend to be missing together, which suggests systematic missingness (for example, if someone skips salary, they often skip compensation too). Most other columns have missing values that look random and aren’t strongly linked. Overall, missing data is a mix of random gaps and systematic skips, mostly driven by question sensitivity and survey design.

# %% [markdown]
# ### 🤖 AI-Assisted Analysis (Task 2.1)
# **AI-Assisted Analysis:**
# [Use AI to help interpret missing data patterns and suggest potential causes]
#
# ---

# %% [markdown]
# Interpretation of Missing Data Patterns:
#
# The bar chart shows that some columns have much higher missing rates than others. These are likely optional questions, sensitive topics (e.g., salary, compensation), or fields that respondents often skip.
# The heatmap and correlation analysis reveal that certain columns tend to have missing values together (systematic missingness). For example, if “Additional Compensation” and “Annual Salary” are highly correlated, respondents who skip one often skip the other.
# Most other columns show low or near-zero correlation in missingness, indicating that their missing values are more random and independent.
# Potential Causes:
#
# Survey Design:
#
# Optional questions or poor question placement may lead to higher missing rates in specific columns.
# Sensitive questions (salary, compensation, demographics) are often skipped due to privacy concerns.
# Respondent Fatigue:
#
# Long surveys can cause participants to skip questions toward the end, resulting in systematic missingness in later columns.
# Technical Issues:
#
# Data entry errors or glitches during survey submission can lead to missing values in multiple columns.
# Conditional Logic:
#
# Some questions may only be shown based on previous answers (e.g., “state” only if “country” is “United States”), causing systematic missingness.
# Manual Entry and Formatting:
#
# Free-text fields and inconsistent formatting can result in missing or unusable data.
# Summary:
#
# Focus on columns with high missing rates and those with systematic missingness for targeted cleaning and imputation.
# Consider survey design improvements and input validation to reduce future missing data.
# For analysis, document which columns are most affected and whether missingness is random or systematic, as this impacts how you handle and interpret the data.

# %% [markdown]
# ## 2.2 Missing Data Strategy
# **Instructions:** For each variable with missing data, justify your imputation strategy

# %%
# Define imputation strategies for each column with missing data
# TODO: For each column with missing values, choose appropriate imputation method
# TODO: Consider the nature of the variable (numerical vs categorical)
# TODO: Consider the percentage of missing values
# TODO: Consider the relationship with other variables

# YOUR CODE HERE:


# TODO: Display imputation strategies

# YOUR CODE HERE:

# %% [markdown]
# For each column with missing values, first check if it’s numerical or categorical.
# If it’s numerical and only a few values are missing, fill with the median or mean. If a lot are missing, consider dropping the column or using group-based imputation.
# For categorical columns, fill with the most common value or add a new “Missing” category. If the missing rate is very high, you might drop the column.
# Always look at the percentage of missing data—if it’s above 40%, be careful about using that column.
# If missingness in one column depends on another (like compensation missing when salary is missing), use group-based imputation or flag those cases.

# %% [markdown]
# ## 2.3 Implementation
# **Instructions:** Implement your chosen imputation methods and compare before/after characteristics

# %%
# Create visualizations showing the impact of imputation
col = 'What is your annual salary?'

# Convert salary columns to numeric, handling commas and errors
salary_before = pd.to_numeric(Salary_original[col].replace(',', '', regex=True), errors='coerce')
salary_after = pd.to_numeric(Salary[col].replace(',', '', regex=True), errors='coerce')

fig, axes = subplots(1, 2, figsize=(12, 5))
axes[0].hist(salary_before.dropna(), bins=30)
axes[0].set_title('Before Imputation')

axes[1].hist(salary_after.dropna(), bins=30)
axes[1].set_title('After Imputation')

fig.tight_layout()
fig.show()
# Out:
# Missing values before imputation:
# Timestamp                                                                                                                                                                                                                               0
# How old are you?                                                                                                                                                                                                                        0
# What industry do you work in?                                                                                                                                                                                                           0
# Job title                                                                                                                                                                                                                               0
# ...

# %% [markdown]
# ### 📝 Analysis Explanation (Task 2.2 & 2.3)
# **Your Analysis:**
# [Discuss your imputation strategy choices and the impact of imputation on the dataset]
#
# ---

# %% [markdown]
# ### 🤖 AI-Assisted Analysis (Task 2.2 & 2.3)
# **AI-Assisted Analysis:**
# [Use AI to help evaluate imputation strategies and their effectiveness]
#
# ---

# %% [markdown]
# # Task 3: Correlation Analysis (1 Point)
#
# ## Numerical Variable Correlations
# **Instructions:**
# - Create a correlation matrix for all numerical variables
# - Generate appropriate visualizations (heatmap, pairplots)
# - Identify the strongest positive and negative correlations

# %%
# Numerical variable correlation analysis
# TODO: Select only numerical columns from the imputed dataset
# TODO: Calculate correlation matrix
# TODO: Create correlation heatmap
# TODO: Identify strongest correlations

# YOUR CODE HERE:


# Find strongest correlations
# TODO: Identify the strongest positive and negative correlations
# YOUR CODE HERE:

# %% [markdown]
# ## Categorical-Numerical Relationships
# **Instructions:** Analyze relationships between categorical and numerical variables

# %%
# Analyze categorical-numerical relationships
# TODO: Select categorical and numerical columns
# TODO: Create visualizations (boxplots, violin plots) showing relationships
# TODO: Focus on salary-related relationships
# TODO: Create visualizations for categorical-numerical relationships
# Example: Salary by different categorical variables

# YOUR CODE HERE:

# %% [markdown]
# ### 📝 Analysis Explanation (Task 3)
# **Your Analysis:**
# [Analyze correlation findings and categorical-numerical relationships]
#
# ---

# %% [markdown]
# ### 🤖 AI-Assisted Analysis (Task 3)
# **AI-Assisted Analysis:**
# [Use AI to help interpret correlations and suggest potential business implications]
#
# ---

# %% [markdown]
# # Task 4: Feature Engineering (1 Point)
#
# ## Create New Variables
# **Instructions:** Design and create at least 3 meaningful new features such as:
# - Experience categories
# - Industry-adjusted salary
# - Location tiers
# - Education-experience interaction
# - Remote work indicator

# %%
# Create new features
# TODO: Create at least 3 meaningful new features
# TODO: Document the rationale for each feature

# YOUR CODE HERE:

# %% [markdown]
# ### 📝 Analysis Explanation (Task 4)
# **Your Analysis:**
# [Explain your feature engineering choices and their business rationale]
#
# ---

# %% [markdown]
# ### 🤖 AI-Assisted Analysis (Task 4)
# **AI-Assisted Analysis:**
# [Use AI to help evaluate feature engineering effectiveness and suggest improvements]
#
# ---

# %% [markdown]
# # Task 5: Data Transformation (1 Point)
#
# ## Numerical Variable Transformations
# **Instructions:**
# - Analyze distributions of numerical variables
# - Apply appropriate transformations to improve normality
# - Handle outliers appropriately

# %%
# Data transformation analysis
# TODO: Analyze distributions of numerical variables
# TODO: Apply appropriate transformations
# TODO: Handle outliers

# YOUR CODE HERE:

# %% [markdown]
# ### 📝 Analysis Explanation (Task 5)
# **Your Analysis:**
# [Discuss transformation choices and their impact on data distributions]
#
# ---

# %% [markdown]
# ### 🤖 AI-Assisted Analysis (Task 5)
# **AI-Assisted Analysis:**
# [Use AI to help evaluate transformation effectiveness and outlier handling strategies]
#
# ---

# %% [markdown]
# # Task 6: Categorical Variable Encoding (1 Point)
#
# ## Encoding Strategy
# **Instructions:** Choose and implement appropriate encoding for each categorical variable:
# - Binary variables: Simple binary encoding
# - Ordinal variables: Label encoding preserving order
# - Nominal variables with few categories: One-hot encoding
# - High-cardinality variables: Target encoding or frequency encoding

# %%
# Categorical variable encoding
# TODO: Choose appropriate encoding for each categorical variable
# TODO: Implement encoding methods
# TODO: Compare dataset before and after encoding

# YOUR CODE HERE:

# %% [markdown]
# ### 📝 Analysis Explanation (Task 6)
# **Your Analysis:**
# [Discuss encoding choices and their impact on dataset dimensions and information preservation]
#
# ---
#
# ### 🤖 AI-Assisted Analysis (Task 6)
# **AI-Assisted Analysis:**
# [Use AI to help evaluate encoding strategies and suggest optimizations]
#
# ---

# %% [markdown]
# ## Survey Completion (2 Points)
# **Don't forget:** Complete the required survey for 2 additional points!
#
# **Survey Link:** [[Qualtrics Survey Please click here](https://fgcu.qualtrics.com/jfe/form/SV_efZVis4pbBj2Gh0)]
#
# ---
